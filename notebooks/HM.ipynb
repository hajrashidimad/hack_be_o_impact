# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_p1_2020 = pd.read_excel("../data/original/2020/HM/HM_2020_P1.xlsx")
df_p2_2020 = pd.read_excel("../data/original/2020/HM/HM_2020_P2.xlsx")
df_p3_2020 = pd.read_excel("../data/original/2020/HM/HM_2020_P3.xlsx")
df_p4_2020 = pd.read_excel("../data/original/2020/HM/HM_2020_P4.xlsx")


df_p1_2019 = pd.read_excel("../data/original/2019/HM/HM_2019_P1.xlsx")
df_p2_2019 = pd.read_excel("../data/original/2019/HM/HM_2019_P2.xlsx")
df_p3_2019 = pd.read_excel("../data/original/2019/HM/HM_2019_P3.xlsx")
df_p4_2019 = pd.read_excel("../data/original/2019/HM/HM_2019_P4.xlsx")

df_p1_2018 = pd.read_excel("../data/original/2018/HM/HM_2018_P1.xlsx")
df_p2_2018 = pd.read_excel("../data/original/2018/HM/HM_2018_P2.xlsx")
df_p3_2018 = pd.read_excel("../data/original/2018/HM/HM_2018_P3.xlsx")
df_p4_2018 = pd.read_excel("../data/original/2018/HM/HM_2018_P4.xlsx")

df_p1_2017 = pd.read_excel("../data/original/2017/HM/HM_2017_P1.xlsx")
df_p2_2017 = pd.read_excel("../data/original/2017/HM/HM_2017_P2.xlsx")
df_p3_2017 = pd.read_excel("../data/original/2017/HM/HM_2017_P3.xlsx")
df_p4_2017 = pd.read_excel("../data/original/2017/HM/HM_2017_P4.xlsx")

df = pd.concat([df_p1_2020,df_p2_2020,df_p3_2020,df_p4_2020,df_p1_2019,df_p2_2019,df_p3_2019,df_p4_2019,df_p1_2018,df_p2_2018,df_p3_2018,df_p4_2018,df_p1_2017,df_p2_2017,df_p3_2017,df_p4_2017])

# %%
df
# Out:
#    REF....SUBSTANCE   PERIOD  Lead  Cadmium  Arsenic  Mercury  Copper  Chrome  \
# 0             B0012  2020/P1  0.88     0.29    0.048      0.0    11.0   0.140
# 1             B0017  2020/P1  0.14     0.42    0.000      0.0     7.9   0.066
# 2             B0019  2020/P1  0.15     0.68    0.000      0.0     7.6   0.071
# 3             B0021  2020/P1  0.16     0.47    0.000      0.0     7.3   0.082
# 4             B0023  2020/P1  0.21     0.73    0.030      0.0     8.1   0.081
# ..              ...      ...   ...      ...      ...      ...     ...     ...
# 8             F0005  2017/P4  0.00     0.18    0.000      0.0     7.8     NaN
# 9             F0009  2017/P4  0.00     0.45    0.049      0.0     7.9     NaN
# 10            F0011  2017/P4  0.00     0.17    0.033      0.0     7.9     NaN
# 11            F0013  2017/P4  0.00     0.16    0.000      0.0     7.1     NaN
# 12            F0015  2017/P4  0.00     0.18    0.000      0.0     6.8     NaN
#
#     Zinc  Chromium
# 0     51       NaN
# 1     45       NaN
# 2     46       NaN
# 3     40       NaN
# 4     48       NaN
# ..   ...       ...
# 8     38     0.020
# 9     33     0.000
# 10    37     0.022
# 11    33     0.017
# 12    34     0.020
#
# [431 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['REF....SUBSTANCE', 'PERIOD', 'Lead', 'Cadmium', 'Arsenic', 'Mercury',
#        'Copper', 'Chrome', 'Zinc', 'Chromium'],
#       dtype='object')

# %%
df.describe()
# Out:
#              Lead     Cadmium     Arsenic     Mercury      Copper      Chrome  \
# count  431.000000  431.000000  431.000000  431.000000  431.000000  365.000000
# mean     0.221285    0.186947    0.037369    0.000427    7.972158    0.107748
# std      0.322265    0.221463    0.040220    0.002567    2.809016    0.091180
# min      0.000000    0.011000    0.000000    0.000000    0.000000    0.015000
# 25%      0.062500    0.060000    0.000000    0.000000    6.600000    0.051000
# 50%      0.130000    0.110000    0.037000    0.000000    7.700000    0.081000
# 75%      0.245000    0.220000    0.057000    0.000000    9.000000    0.120000
# max      3.000000    2.100000    0.340000    0.042000   37.000000    0.710000
#
#              Zinc   Chromium
# count  431.000000  66.000000
# mean    38.679814   0.088727
# std     10.387808   0.144092
# min     15.000000   0.000000
# 25%     32.000000   0.027250
# 50%     37.000000   0.044000
# 75%     44.000000   0.112250
# max    108.000000   1.100000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 431 entries, 0 to 12
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   REF....SUBSTANCE  431 non-null    object
#  1   PERIOD            431 non-null    object
#  2   Lead              431 non-null    float64
#  3   Cadmium           431 non-null    float64
#  4   Arsenic           431 non-null    float64
#  5   Mercury           431 non-null    float64
#  6   Copper            431 non-null    float64
#  7   Chrome            365 non-null    float64
#  8   Zinc              431 non-null    int64
#  9   Chromium          66 non-null     float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 37.0+ KB

# %%
df['SEASON'] = df['PERIOD'].str[-2:]

# %%
size = len("2020/P1")
df['PERIOD'] = df['PERIOD'].str[:size -3]

# %%
#df.to_csv("../data/interim/HM.csv")

# %%
df
df['PERIOD'] = df['PERIOD'].astype(int)

# %%
# Does Chrome is equal to chromium ? 
df[df.isna().any(axis=1)]
# Out:
#    REF....SUBSTANCE  PERIOD  Lead  Cadmium  Arsenic  Mercury  Copper  Chrome  \
# 0             B0012    2020  0.88     0.29    0.048      0.0    11.0   0.140
# 1             B0017    2020  0.14     0.42    0.000      0.0     7.9   0.066
# 2             B0019    2020  0.15     0.68    0.000      0.0     7.6   0.071
# 3             B0021    2020  0.16     0.47    0.000      0.0     7.3   0.082
# 4             B0023    2020  0.21     0.73    0.030      0.0     8.1   0.081
# ..              ...     ...   ...      ...      ...      ...     ...     ...
# 8             F0005    2017  0.00     0.18    0.000      0.0     7.8     NaN
# 9             F0009    2017  0.00     0.45    0.049      0.0     7.9     NaN
# 10            F0011    2017  0.00     0.17    0.033      0.0     7.9     NaN
# 11            F0013    2017  0.00     0.16    0.000      0.0     7.1     NaN
# 12            F0015    2017  0.00     0.18    0.000      0.0     6.8     NaN
#
#     Zinc  Chromium SEASON
# 0     51       NaN     P1
# 1     45       NaN     P1
# 2     46       NaN     P1
# 3     40       NaN     P1
# 4     48       NaN     P1
# ..   ...       ...    ...
# 8     38     0.020     P4
# 9     33     0.000     P4
# 10    37     0.022     P4
# 11    33     0.017     P4
# 12    34     0.020     P4
#
# [431 rows x 11 columns]

# %%
df.Chrome = df.Chrome.fillna(df.Chromium)
del df['Chromium']
dataset['SEASON'] = dataset['SEASON'].map( {'P1': 0, 'P2': 1,'P3':2,'P4':3} ).astype(int)

# %%
df.dtypes
# Out:
# REF....SUBSTANCE     object
# PERIOD                int64
# Lead                float64
# Cadmium             float64
# Arsenic             float64
# Mercury             float64
# Copper              float64
# Chrome              float64
# Zinc                  int64
# SEASON               object
# dtype: object

# %%
pearsoncorr = df.corr()
fig_dims = (15, 8)
fig = plt.subplots(figsize=fig_dims)
sns.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
period = df.groupby(by='PERIOD').sum()
season = df.groupby(by='SEASON').sum()

# %%
period
# Out:
#           Lead  Cadmium  Arsenic  Mercury  Copper  Chrome  Zinc
# PERIOD
# 2017     8.644   12.496    1.606    0.016   506.7   5.856  2557
# 2018    17.557   20.562    5.484    0.063   834.0   9.939  4058
# 2019    27.983   24.590    3.939    0.052   849.4  11.512  4430
# 2020    41.190   22.926    5.077    0.053  1245.9  17.877  5626

# %%
season
# Out:
#         PERIOD    Lead  Cadmium  Arsenic  Mercury  Copper  Chrome  Zinc
# SEASON
# P1      248311  28.569   27.368    3.212    0.082   962.6  11.220  4936
# P2      248309  25.722   15.011    4.548    0.034  1035.5  12.273  5280
# P3      232166  25.506   14.091    5.813    0.039   879.7  13.505  3958
# P4      141314  15.577   24.104    2.533    0.029   558.2   8.186  2497

# %%
# BAR PLOT BY SEASON
for i, col in enumerate (season.columns):
    season[col].plot.bar(fig=plt.figure(i))
    plt.title(col)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# BAR PLOT BY PERIOD FOR THE PERIOD
for i, col in enumerate (period.columns):
    season[col].plot.bar(fig=plt.figure(i))
    plt.title(col)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# CORRELATION MATRIX FOR THE SEASON
pearsoncorr = season.corr()
fig_dims = (15, 8)
fig = plt.subplots(figsize=fig_dims)
sns.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
# CORRELATION MATRIX FOR THE PERIOD
pearsoncorr = period.corr()
fig_dims = (15, 8)
fig = plt.subplots(figsize=fig_dims)
sns.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
# Out:
# <AxesSubplot:>
