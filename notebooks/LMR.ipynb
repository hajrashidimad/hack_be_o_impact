# %%
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
lmr_pest = pd.read_excel("../data/original/pesticides.xlsx")
lmr_hm = pd.read_csv("../data/original/LMR.txt", sep="\t")

# %%
lmr_pest.head(250)
# Out:
#                importName                       name          statusEN    LMR                         familyEN                                        typeEN
# 0               Aclonifen                  aclonifen        authorized   0.05                   diphenyl ether                                     herbicide
# 1                  Aldrin                     aldrin        prohibited   0.01                   organochlorine                                   insecticide
# 2            Ametoctradin               ametoctradin        authorized   0.05               triazolopyrimidine                                     fungicide
# 3           Anthraquinone              anthraquinone        prohibited   0.02  polycyclic aromatic hydrocarbon                                bird repellant
# 4            Azoxystrobin               azoxystrobin        authorized   0.05                      strobilurin                                     fungicide
# ...

# %%
#lmr_pest[lmr_pest.importName == "Aldrin"]["LMR"]
# Out:
# 1    0.01
# Name: LMR, dtype: float64

# %%
#lmr_pest[lmr_pest.importName == "Aldrin"]["typeEN"]
# Out:
# 1    insecticide
# Name: typeEN, dtype: object

# %%
#filter_info = lmr_pest.importName == "Aldrin"
#lmr_pest.loc[filter_info, "typeEN"] = 'blabla'

# %%
lmr_pest.importName == "Aldrin"
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
lmr_pest.typeEN.unique()
# Out:
# array(['herbicide', 'insecticide', 'fungicide', 'bird repellant',
#        'growth regulator, fungicide and insecticide',
#        'insecticide, molluscicide and bird repellent', 'acaricide',
#        'fungicide and growth regulator', 'growth regulator', nan],
#       dtype=object)

# %%
lmr_hm.head()
# Out:
#    Lead  Cadmium  Arsenic  Mercury  Copper  Chrome  Zinc  Unnamed: 7
# 0   1.5        1      0.3        1      30     NaN   NaN         NaN
