# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_dist_1 = pd.read_csv("../../data/interim/distsOneSheet_clc_1.csv", skiprows=2)

# %%
df_dist_1.columns = ['Site', '1', '2', '3', '4', '5']
df_dist_1.head()
# Out:
#     Site            1            2           3           4          5
# 0  B0012   491.383828  1087.774122  934.164041         NaN  55.262657
# 1  B0017   843.971690   833.691581  792.501380         NaN        NaN
# 2  B0019          NaN          NaN  662.515291  462.433522        NaN
# 3  B0021          NaN  1193.174294  560.864627  365.900871        NaN
# 4  B0023  1223.368654   301.686590  791.924039    0.000000        NaN

# %% [markdown]
# ## Répartition // CLC1

# %%
sns.boxplot(data=df_dist_1)
plt.show()

# %% [markdown]
# ## Répartition // CLC // Site

# %%
sns.scatterplot(data=df_dist_1)
plt.show()
