# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_hm = pd.read_csv("../../data/interim/HM.csv")
#df_pesticide = pd.read_csv("../../data/interim/HM.csv")

# %%
df_hm['Presence_Lead'] = df_hm['Lead'] > 0
df_hm['Presence_Cadmium'] = df_hm['Cadmium'] > 0
df_hm['Presence_Arsenic'] = df_hm['Arsenic'] > 0
df_hm['Presence_Mercury'] = df_hm['Mercury'] > 0
df_hm['Presence_Copper'] = df_hm['Copper'] > 0
df_hm
# Out:
# 2    2018  0.077    0.470    0.000    0.000     8.0   0.045    42       3       False          False          False          False         False      True           True              True             False             False             True
# 355            B0061    2018  0.140    0.540    0.040    0.000     7.7   0.120    35       3       False          False          False          False         False      True           True              True              True             False             True
# 356            B0069    2018  0.110    0.290    0.000    0.000     6.1   0.052    31       3       False          False          False          False         False      True           True              True             False             False             True
# ...
